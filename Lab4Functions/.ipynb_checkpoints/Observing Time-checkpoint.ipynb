# %%
from astropy.coordinates import SkyCoord, AltAz, EarthLocation, Galactic
from astropy.time import Time
import astropy.units as u
from astroplan import Observer
import numpy as np
import pytz
import datetime
# Out:
# Requirement already satisfied: astroplan in /Users/andreschirino-segura/anaconda3/lib/python3.11/site-packages (0.10.1)
# Requirement already satisfied: numpy>=1.17 in /Users/andreschirino-segura/anaconda3/lib/python3.11/site-packages (from astroplan) (1.26.4)
# Requirement already satisfied: astropy>=4 in /Users/andreschirino-segura/anaconda3/lib/python3.11/site-packages (from astroplan) (6.1.3)
# Requirement already satisfied: pytz in /Users/andreschirino-segura/anaconda3/lib/python3.11/site-packages (from astroplan) (2024.1)
# Requirement already satisfied: six in /Users/andreschirino-segura/anaconda3/lib/python3.11/site-packages (from astroplan) (1.16.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/andreschirino-segura/anaconda3/lib/python3.11/site-packages (from astropy>=4->astroplan) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.7.29.0.32.7 in /Users/andreschirino-segura/anaconda3/lib/python3.11/site-packages (from astropy>=4->astroplan) (0.2024.9.2.0.33.23)
# Requirement already satisfied: PyYAML>=3.13 in /Users/andreschirino-segura/anaconda3/lib/python3.11/site-packages (from astropy>=4->astroplan) (6.0.2)
# Requirement already satisfied: packaging>=19.0 in /Users/andreschirino-segura/anaconda3/lib/python3.11/site-packages (from astropy>=4->astroplan) (24.1)

# %%
def track_galactic_pst(l_deg, b_deg, year, month, day, latitude_deg, longitude_deg, elevation_m=0):
    # Timezone-aware observer in US/Pacific
    timezone = 'US/Pacific'
    location = EarthLocation(lat=latitude_deg*u.deg, lon=longitude_deg*u.deg, height=elevation_m*u.m)
    observer = Observer(location=location, timezone=timezone)

    # Construct timezone-aware datetime objects at local time
    local_zone = pytz.timezone(timezone)
    base_date = datetime.datetime(year, month, day, tzinfo=local_zone)
    datetimes_local = [base_date.replace(hour=hr) for hr in range(24)]

    # Convert to astropy Time
    times = Time(datetimes_local)

    # Convert galactic to ICRS (RA, Dec)
    galactic = SkyCoord(l=l_deg*u.deg, b=b_deg*u.deg, frame='galactic')
    target_icrs = galactic.transform_to('icrs')

    # Compute AltAz frame for each time
    altaz_frame = AltAz(obstime=times, location=location)
    target_altaz = target_icrs.transform_to(altaz_frame)

    # Output
    print(f"Tracking Galactic coord (l={l_deg}°, b={b_deg}°) on {year}-{month:02d}-{day:02d} PST/PDT")
    print(f"{'Local Hour':>10} | {'Altitude (deg)':>14} | {'Azimuth (deg)':>13}")
    print("-" * 42)
    for dt, alt, az in zip(datetimes_local, target_altaz.alt, target_altaz.az):
        hour_label = dt.strftime("%H:%M")
        print(f"{hour_label:>10} | {alt:.6} | {az:.6}")

# %%
def track_multiple_galactic_pst(l_array, b_array, year, month, day, latitude_deg, longitude_deg, elevation_m=0):
    from astropy.coordinates import EarthLocation, AltAz, SkyCoord
    from astropy.time import Time
    from astropy.coordinates import Angle
    import astropy.units as u
    import pytz
    import datetime
    from astroplan import Observer

    assert len(l_array) == len(b_array), "l_array and b_array must be the same length."

    timezone = 'US/Pacific'
    location = EarthLocation(lat=latitude_deg*u.deg, lon=longitude_deg*u.deg, height=elevation_m*u.m)
    observer = Observer(location=location, timezone=timezone)

    local_zone = pytz.timezone(timezone)
    base_date = datetime.datetime(year, month, day, tzinfo=local_zone)
    datetimes_local = [base_date.replace(hour=hr) for hr in range(24)]
    times = Time(datetimes_local)

    results = []

    for l_deg, b_deg in zip(l_array, b_array):
        galactic = SkyCoord(l=l_deg*u.deg, b=b_deg*u.deg, frame='galactic')
        target_icrs = galactic.transform_to('icrs')
        altaz_frame = AltAz(obstime=times, location=location)
        target_altaz = target_icrs.transform_to(altaz_frame)

        coord_results = {
            'l': l_deg,
            'b': b_deg,
            'altitudes': target_altaz.alt.deg,
            'azimuths': target_altaz.az.deg,
            'hours': [dt.strftime("%H:%M") for dt in datetimes_local]
        }

        results.append(coord_results)

    return results

# %%
def hourly_visibility_percentage(l_array, b_array, year, month, day, latitude_deg, longitude_deg, elevation_m=0):
    from astropy.coordinates import EarthLocation, AltAz, SkyCoord
    from astropy.time import Time
    import astropy.units as u
    import pytz
    import datetime
    from astroplan import Observer
    import numpy as np
    import pandas as pd

    assert len(l_array) == len(b_array), "l_array and b_array must be the same length."
    n_points = len(l_array)

    timezone = 'US/Pacific'
    location = EarthLocation(lat=latitude_deg*u.deg, lon=longitude_deg*u.deg, height=elevation_m*u.m)
    observer = Observer(location=location, timezone=timezone)

    local_zone = pytz.timezone(timezone)
    base_date = datetime.datetime(year, month, day, tzinfo=local_zone)
    datetimes_local = [base_date.replace(hour=hr) for hr in range(24)]
    times = Time(datetimes_local)

    # Store results
    results = []

    for time, dt_local in zip(times, datetimes_local):
        visible_count = 0
        for l_deg, b_deg in zip(l_array, b_array):
            galactic = SkyCoord(l=l_deg*u.deg, b=b_deg*u.deg, frame='galactic')
            target_icrs = galactic.transform_to('icrs')
            altaz = target_icrs.transform_to(AltAz(obstime=time, location=location))

            az = altaz.az.deg
            alt = altaz.alt.deg

            # Visibility conditions
            az_condition = not (az >= 355 or az <= 5)
            alt_condition = 14 < alt < 85

            if az_condition and alt_condition:
                visible_count += 1

        visibility_percent = 100.0 * visible_count / n_points
        results.append({
            'Hour': dt_local.strftime('%H:%M'),
            'Visible %': round(visibility_percent, 1)
        })

    return pd.DataFrame(results)

# %%
track_multiple_galactic_pst(l_array, b_array, year, month, day, latitude_deg, longitude_deg, elevation_m=0)

# %%
l = coord_array[:,0] 
b = coord_array[:,1]

# %%
# Example usage
hourly_visibility_percentage(
    l_array=l,         # Galactic longitude
     b_array=b,          # Galactic latitude
    year=2025,
    month=4,
    day=26,
    latitude_deg=37.87, # e.g., Berkeley, CA
    longitude_deg=-122.27,
    elevation_m=580
)
# Out:
#      Hour  Visible %
# 0   00:00       84.5
# 1   01:00       82.5
# 2   02:00       78.0
# 3   03:00       73.1
# 4   04:00       67.0
# 5   05:00       64.7
# 6   06:00       60.5
# 7   07:00       60.5
# 8   08:00       65.4
# 9   09:00       70.2
# 10  10:00       73.1
# 11  11:00       77.3
# 12  12:00       81.2
# 13  13:00       81.6
# 14  14:00       83.2
# 15  15:00       82.8
# 16  16:00       80.3
# 17  17:00       81.2
# 18  18:00       82.2
# 19  19:00       79.3
# 20  20:00       80.6
# 21  21:00       83.2
# 22  22:00       86.4
# 23  23:00       85.1

# %%
# Example usage
track_galactic_pst(
    l_deg=[1],         # Galactic longitude
    b_deg=[0,1],          # Galactic latitude
    year=2025,
    month=4,
    day=18,
    latitude_deg=37.87, # e.g., Berkeley, CA
    longitude_deg=-122.27
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Example usage
# ----> 2 track_galactic_pst(
#       3     l_deg=[1],         # Galactic longitude
#       4     b_deg=[0,1],          # Galactic latitude
#       5     year=2025,
#       6     month=4,
#       7     day=18,
#       8     latitude_deg=37.87, # e.g., Berkeley, CA
#       9     longitude_deg=-122.27
#      10 )
#
# NameError: name 'track_galactic_pst' is not defined

# %%
# Example usage
track_galactic_pst(
    l_deg=105.0,         # Galactic longitude
    b_deg=15.0,          # Galactic latitude
    year=2025,
    month=4,
    day=17,
    latitude_deg=37.87, # e.g., Berkeley, CA
    longitude_deg=-122.27
)
# Out:
# Tracking Galactic coord (l=105.0°, b=15.0°) on 2025-04-17 PST/PDT
# Local Hour | Altitude (deg) | Azimuth (deg)
# ------------------------------------------
#      00:00 | 27.6419 deg | 21.2664 deg
#      01:00 | 32.2468 deg | 24.2056 deg
#      02:00 | 37.3024 deg | 25.9818 deg
#      03:00 | 42.5585 deg | 26.2947 deg
#      04:00 | 47.7068 deg | 24.7539 deg
#      05:00 | 52.3528 deg | 20.9034 deg
#      06:00 | 55.9962 deg | 14.4083 deg
#      07:00 | 58.0816 deg | 5.51929 deg
#      08:00 | 58.1937 deg | 355.545 deg
#      09:00 | 56.3076 deg | 346.455 deg
#      10:00 | 52.8068 deg | 339.672 deg
#      11:00 | 48.2437 deg | 335.545 deg
#      12:00 | 43.1289 deg | 333.775 deg
#      13:00 | 37.8683 deg | 333.908 deg
#      14:00 | 32.778 deg | 335.541 deg
#      15:00 | 28.1134 deg | 338.366 deg
#      16:00 | 24.0889 deg | 342.142 deg
#      17:00 | 20.8862 deg | 346.661 deg
#      18:00 | 18.653 deg | 351.724 deg
#      19:00 | 17.4957 deg | 357.124 deg
#      20:00 | 17.4711 deg | 2.64006 deg
#      21:00 | 18.5804 deg | 8.04914 deg
#      22:00 | 20.7691 deg | 13.1311 deg
#      23:00 | 23.9328 deg | 17.6779 deg

# %%
# Example usage
track_galactic_pst(
    l_deg=105.0,         # Galactic longitude
    b_deg=50.0,          # Galactic latitude
    year=2025,
    month=4,
    day=17,
    latitude_deg=37.87, # e.g., Berkeley, CA
    longitude_deg=-122.27
)
# Out:
# Tracking Galactic coord (l=105.0°, b=50.0°) on 2025-04-17 PST/PDT
# Local Hour | Altitude (deg) | Azimuth (deg)
# ------------------------------------------
#      00:00 | 62.5336 deg | 17.0869 deg
#      01:00 | 64.6114 deg | 2.58557 deg
#      02:00 | 63.5349 deg | 347.276 deg
#      03:00 | 59.678 deg | 335.553 deg
#      04:00 | 54.0568 deg | 328.649 deg
#      05:00 | 47.5676 deg | 325.627 deg
#      06:00 | 40.8079 deg | 325.349 deg
#      07:00 | 34.1766 deg | 327.023 deg
#      08:00 | 27.971 deg | 330.164 deg
#      09:00 | 22.44 deg | 334.468 deg
#      10:00 | 17.8064 deg | 339.716 deg
#      11:00 | 14.2694 deg | 345.715 deg
#      12:00 | 11.9949 deg | 352.256 deg
#      13:00 | 11.0973 deg | 359.097 deg
#      14:00 | 11.6239 deg | 5.97411 deg
#      15:00 | 13.547 deg | 12.6177 deg
#      16:00 | 16.768 deg | 18.7796 deg
#      17:00 | 21.1329 deg | 24.2429 deg
#      18:00 | 26.4499 deg | 28.8128 deg
#      19:00 | 32.5018 deg | 32.2827 deg
#      20:00 | 39.0478 deg | 34.3783 deg
#      21:00 | 45.807 deg | 34.6722 deg
#      22:00 | 52.4145 deg | 32.4656 deg
#      23:00 | 58.3362 deg | 26.6972 deg

# %%
# Example usage
track_galactic_pst(
    l_deg=160.0,         # Galactic longitude
    b_deg=15.0,          # Galactic latitude
    year=2025,
    month=4,
    day=17,
    latitude_deg=37.87, # e.g., Berkeley, CA
    longitude_deg=-122.27
)
# Out:
# Tracking Galactic coord (l=160.0°, b=15.0°) on 2025-04-17 PST/PDT
# Local Hour | Altitude (deg) | Azimuth (deg)
# ------------------------------------------
#      00:00 | 19.4215 deg | 323.681 deg
#      01:00 | 12.9206 deg | 330.057 deg
#      02:00 | 7.65362 deg | 337.386 deg
#      03:00 | 3.86801 deg | 345.514 deg
#      04:00 | 1.77232 deg | 354.203 deg
#      05:00 | 1.49534 deg | 3.13031 deg
#      06:00 | 3.05489 deg | 11.9279 deg
#      07:00 | 6.35309 deg | 20.2533 deg
#      08:00 | 11.2011 deg | 27.8414 deg
#      09:00 | 17.359 deg | 34.5155 deg
#      10:00 | 24.572 deg | 40.1549 deg
#      11:00 | 32.5911 deg | 44.6307 deg
#      12:00 | 41.1744 deg | 47.7088 deg
#      13:00 | 50.065 deg | 48.8758 deg
#      14:00 | 58.9226 deg | 46.9409 deg
#      15:00 | 67.1171 deg | 39.0407 deg
#      16:00 | 73.1015 deg | 19.2662 deg
#      17:00 | 73.8625 deg | 347.602 deg
#      18:00 | 68.8075 deg | 324.257 deg
#      19:00 | 60.9358 deg | 314.211 deg
#      20:00 | 52.158 deg | 311.232 deg
#      21:00 | 43.239 deg | 311.818 deg
#      22:00 | 34.5593 deg | 314.511 deg
#      23:00 | 26.3864 deg | 318.687 deg

# %%
# Example usage
track_galactic_pst(
    l_deg=160.0,         # Galactic longitude
    b_deg=50.0,          # Galactic latitude
    year=2025,
    month=4,
    day=18,
    latitude_deg=37.87, # e.g., Berkeley, CA
    longitude_deg=-122.27
)
# Out:
# Tracking Galactic coord (l=160.0°, b=50.0°) on 2025-04-18 PST/PDT
# Local Hour | Altitude (deg) | Azimuth (deg)
# ------------------------------------------
#      00:00 | 52.5313 deg | 311.356 deg
#      01:00 | 43.6199 deg | 311.816 deg
#      02:00 | 34.9336 deg | 314.425 deg
#      03:00 | 26.7428 deg | 318.537 deg
#      04:00 | 19.2902 deg | 323.862 deg
#      05:00 | 12.822 deg | 330.253 deg
#      06:00 | 7.5926 deg | 337.594 deg
#      07:00 | 3.8486 deg | 345.729 deg
#      08:00 | 1.79669 deg | 354.417 deg
#      09:00 | 1.5631 deg | 3.3344 deg
#      10:00 | 3.16283 deg | 12.1141 deg
#      11:00 | 6.49573 deg | 20.4152 deg
#      12:00 | 11.3717 deg | 27.9747 deg
#      13:00 | 17.5505 deg | 34.6179 deg
#      14:00 | 24.7777 deg | 40.2238 deg
#      15:00 | 32.8045 deg | 44.6615 deg
#      16:00 | 41.389 deg | 47.6921 deg
#      17:00 | 50.273 deg | 48.7909 deg
#      18:00 | 59.1118 deg | 46.7423 deg
#      19:00 | 67.2618 deg | 38.6307 deg
#      20:00 | 73.144 deg | 18.5403 deg
#      21:00 | 73.7514 deg | 346.942 deg
#      22:00 | 68.6123 deg | 324.008 deg
#      23:00 | 60.7212 deg | 314.183 deg

# %%
import numpy as np
from astropy.coordinates import SkyCoord
import astropy.units as u

# Define galactic latitude range and spacing
b_vals = np.linspace(15, 50, int((50 - 15) / 2.4) + 1)  # inclusive
coord_list = []

for b in b_vals:
    cosb = np.cos(np.deg2rad(b))
    dell = 2.4 / cosb
    l_vals = np.linspace(105, 160, int((160 - 105) / dell) + 1)
    for l in l_vals:
        coord = SkyCoord(l=l*u.deg, b=b*u.deg, frame='galactic')
        coord_list.append(coord)

# Optional: Convert to RA/Dec
radec_list = [coord.transform_to('icrs') for coord in coord_list]

# Output example: matrix of (l, b)
coord_matrix = np.array([(c.l.deg, c.b.deg) for c in coord_list])
coord_matrix
# Out:
# array([[105.        ,  15.        ],
#        [107.5       ,  15.        ],
#        [110.        ,  15.        ],
#        [112.5       ,  15.        ],
#        [115.        ,  15.        ],
#        [117.5       ,  15.        ],
#        [120.        ,  15.        ],
#        [122.5       ,  15.        ],
#        [125.        ,  15.        ],
#        [127.5       ,  15.        ],
#        [130.        ,  15.        ],
#        [132.5       ,  15.        ],
#        [135.        ,  15.        ],
#        [137.5       ,  15.        ],
#        [140.        ,  15.        ],
#        [142.5       ,  15.        ],
#        [145.        ,  15.        ],
#        [147.5       ,  15.        ],
#        [150.        ,  15.        ],
#        [152.5       ,  15.        ],
#        [155.        ,  15.        ],
#        [157.5       ,  15.        ],
#        [160.        ,  15.        ],
#        [105.        ,  17.5       ],
#        [107.61904762,  17.5       ],
#        [110.23809524,  17.5       ],
#        [112.85714286,  17.5       ],
#        [115.47619048,  17.5       ],
#        [118.0952381 ,  17.5       ],
#        [120.71428571,  17.5       ],
#        [123.33333333,  17.5       ],
#        [125.95238095,  17.5       ],
#        [128.57142857,  17.5       ],
#        [131.19047619,  17.5       ],
#        [133.80952381,  17.5       ],
#        [136.42857143,  17.5       ],
#        [139.04761905,  17.5       ],
#        [141.66666667,  17.5       ],
#        [144.28571429,  17.5       ],
#        [146.9047619 ,  17.5       ],
#        [149.52380952,  17.5       ],
#        [152.14285714,  17.5       ],
#        [154.76190476,  17.5       ],
#        [157.38095238,  17.5       ],
#        [160.        ,  17.5       ],
#        [105.        ,  20.        ],
#        [107.61904762,  20.        ],
#        [110.23809524,  20.        ],
#        [112.85714286,  20.        ],
#        [115.47619048,  20.        ],
#        [118.0952381 ,  20.        ],
#        [120.71428571,  20.        ],
#        [123.33333333,  20.        ],
#        [125.95238095,  20.        ],
#        [128.57142857,  20.        ],
#        [131.19047619,  20.        ],
#        [133.80952381,  20.        ],
#        [136.42857143,  20.        ],
#        [139.04761905,  20.        ],
#        [141.66666667,  20.        ],
#        [144.28571429,  20.        ],
#        [146.9047619 ,  20.        ],
#        [149.52380952,  20.        ],
#        [152.14285714,  20.        ],
#        [154.76190476,  20.        ],
#        [157.38095238,  20.        ],
#        [160.        ,  20.        ],
#        [105.        ,  22.5       ],
#        [107.61904762,  22.5       ],
#        [110.23809524,  22.5       ],
#        [112.85714286,  22.5       ],
#        [115.47619048,  22.5       ],
#        [118.0952381 ,  22.5       ],
#        [120.71428571,  22.5       ],
#        [123.33333333,  22.5       ],
#        [125.95238095,  22.5       ],
#        [128.57142857,  22.5       ],
#        [131.19047619,  22.5       ],
#        [133.80952381,  22.5       ],
#        [136.42857143,  22.5       ],
#        [139.04761905,  22.5       ],
#        [141.66666667,  22.5       ],
#        [144.28571429,  22.5       ],
#        [146.9047619 ,  22.5       ],
#        [149.52380952,  22.5       ],
#        [152.14285714,  22.5       ],
#        [154.76190476,  22.5       ],
#        [157.38095238,  22.5       ],
#        [160.        ,  22.5       ],
#        [105.        ,  25.        ],
#        [107.75      ,  25.        ],
#        [110.5       ,  25.        ],
#        [113.25      ,  25.        ],
#        [116.        ,  25.        ],
#        [118.75      ,  25.        ],
#        [121.5       ,  25.        ],
#        [124.25      ,  25.        ],
#        [127.        ,  25.        ],
#        [129.75      ,  25.        ],
#        [132.5       ,  25.        ],
#        [135.25      ,  25.        ],
#        [138.        ,  25.        ],
#        [140.75      ,  25.        ],
#        [143.5       ,  25.        ],
#        [146.25      ,  25.        ],
#        [149.        ,  25.        ],
#        [151.75      ,  25.        ],
#        [154.5       ,  25.        ],
#        [157.25      ,  25.        ],
#        [160.        ,  25.        ],
#        [105.        ,  27.5       ],
#        [107.75      ,  27.5       ],
#        [110.5       ,  27.5       ],
#        [113.25      ,  27.5       ],
#        [116.        ,  27.5       ],
#        [118.75      ,  27.5       ],
#        [121.5       ,  27.5       ],
#        [124.25      ,  27.5       ],
#        [127.        ,  27.5       ],
#        [129.75      ,  27.5       ],
#        [132.5       ,  27.5       ],
#        [135.25      ,  27.5       ],
#        [138.        ,  27.5       ],
#        [140.75      ,  27.5       ],
#        [143.5       ,  27.5       ],
#        [146.25      ,  27.5       ],
#        [149.        ,  27.5       ],
#        [151.75      ,  27.5       ],
#        [154.5       ,  27.5       ],
#        [157.25      ,  27.5       ],
#        [160.        ,  27.5       ],
#        [105.        ,  30.        ],
#        [107.89473684,  30.        ],
#        [110.78947368,  30.        ],
#        [113.68421053,  30.        ],
#        [116.57894737,  30.        ],
#        [119.47368421,  30.        ],
#        [122.36842105,  30.        ],
#        [125.26315789,  30.        ],
#        [128.15789474,  30.        ],
#        [131.05263158,  30.        ],
#        [133.94736842,  30.        ],
#        [136.84210526,  30.        ],
#        [139.73684211,  30.        ],
#        [142.63157895,  30.        ],
#        [145.52631579,  30.        ],
#        [148.42105263,  30.        ],
#        [151.31578947,  30.        ],
#        [154.21052632,  30.        ],
#        [157.10526316,  30.        ],
#        [160.        ,  30.        ],
#        [105.        ,  32.5       ],
#        [107.89473684,  32.5       ],
#        [110.78947368,  32.5       ],
#        [113.68421053,  32.5       ],
#        [116.57894737,  32.5       ],
#        [119.47368421,  32.5       ],
#        [122.36842105,  32.5       ],
#        [125.26315789,  32.5       ],
#        [128.15789474,  32.5       ],
#        [131.05263158,  32.5       ],
#        [133.94736842,  32.5       ],
#        [136.84210526,  32.5       ],
#        [139.73684211,  32.5       ],
#        [142.63157895,  32.5       ],
#        [145.52631579,  32.5       ],
#        [148.42105263,  32.5       ],
#        [151.31578947,  32.5       ],
#        [154.21052632,  32.5       ],
#        [157.10526316,  32.5       ],
#        [160.        ,  32.5       ],
#        [105.        ,  35.        ],
#        [108.05555556,  35.        ],
#        [111.11111111,  35.        ],
#        [114.16666667,  35.        ],
#        [117.22222222,  35.        ],
#        [120.27777778,  35.        ],
#        [123.33333333,  35.        ],
#        [126.38888889,  35.        ],
#        [129.44444444,  35.        ],
#        [132.5       ,  35.        ],
#        [135.55555556,  35.        ],
#        [138.61111111,  35.        ],
#        [141.66666667,  35.        ],
#        [144.72222222,  35.        ],
#        [147.77777778,  35.        ],
#        [150.83333333,  35.        ],
#        [153.88888889,  35.        ],
#        [156.94444444,  35.        ],
#        [160.        ,  35.        ],
#        [105.        ,  37.5       ],
#        [108.05555556,  37.5       ],
#        [111.11111111,  37.5       ],
#        [114.16666667,  37.5       ],
#        [117.22222222,  37.5       ],
#        [120.27777778,  37.5       ],
#        [123.33333333,  37.5       ],
#        [126.38888889,  37.5       ],
#        [129.44444444,  37.5       ],
#        [132.5       ,  37.5       ],
#        [135.55555556,  37.5       ],
#        [138.61111111,  37.5       ],
#        [141.66666667,  37.5       ],
#        [144.72222222,  37.5       ],
#        [147.77777778,  37.5       ],
#        [150.83333333,  37.5       ],
#        [153.88888889,  37.5       ],
#        [156.94444444,  37.5       ],
#        [160.        ,  37.5       ],
#        [105.        ,  40.        ],
#        [108.23529412,  40.        ],
#        [111.47058824,  40.        ],
#        [114.70588235,  40.        ],
#        [117.94117647,  40.        ],
#        [121.17647059,  40.        ],
#        [124.41176471,  40.        ],
#        [127.64705882,  40.        ],
#        [130.88235294,  40.        ],
#        [134.11764706,  40.        ],
#        [137.35294118,  40.        ],
#        [140.58823529,  40.        ],
#        [143.82352941,  40.        ],
#        [147.05882353,  40.        ],
#        [150.29411765,  40.        ],
#        [153.52941176,  40.        ],
#        [156.76470588,  40.        ],
#        [160.        ,  40.        ],
#        [105.        ,  42.5       ],
#        [108.4375    ,  42.5       ],
#        [111.875     ,  42.5       ],
#        [115.3125    ,  42.5       ],
#        [118.75      ,  42.5       ],
#        [122.1875    ,  42.5       ],
#        [125.625     ,  42.5       ],
#        [129.0625    ,  42.5       ],
#        [132.5       ,  42.5       ],
#        [135.9375    ,  42.5       ],
#        [139.375     ,  42.5       ],
#        [142.8125    ,  42.5       ],
#        [146.25      ,  42.5       ],
#        [149.6875    ,  42.5       ],
#        [153.125     ,  42.5       ],
#        [156.5625    ,  42.5       ],
#        [160.        ,  42.5       ],
#        [105.        ,  45.        ],
#        [108.4375    ,  45.        ],
#        [111.875     ,  45.        ],
#        [115.3125    ,  45.        ],
#        [118.75      ,  45.        ],
#        [122.1875    ,  45.        ],
#        [125.625     ,  45.        ],
#        [129.0625    ,  45.        ],
#        [132.5       ,  45.        ],
#        [135.9375    ,  45.        ],
#        [139.375     ,  45.        ],
#        [142.8125    ,  45.        ],
#        [146.25      ,  45.        ],
#        [149.6875    ,  45.        ],
#        [153.125     ,  45.        ],
#        [156.5625    ,  45.        ],
#        [160.        ,  45.        ],
#        [105.        ,  47.5       ],
#        [108.66666667,  47.5       ],
#        [112.33333333,  47.5       ],
#        [116.        ,  47.5       ],
#        [119.66666667,  47.5       ],
#        [123.33333333,  47.5       ],
#        [127.        ,  47.5       ],
#        [130.66666667,  47.5       ],
#        [134.33333333,  47.5       ],
#        [138.        ,  47.5       ],
#        [141.66666667,  47.5       ],
#        [145.33333333,  47.5       ],
#        [149.        ,  47.5       ],
#        [152.66666667,  47.5       ],
#        [156.33333333,  47.5       ],
#        [160.        ,  47.5       ],
#        [105.        ,  50.        ],
#        [108.92857143,  50.        ],
#        [112.85714286,  50.        ],
#        [116.78571429,  50.        ],
#        [120.71428571,  50.        ],
#        [124.64285714,  50.        ],
#        [128.57142857,  50.        ],
#        [132.5       ,  50.        ],
#        [136.42857143,  50.        ],
#        [140.35714286,  50.        ],
#        [144.28571429,  50.        ],
#        [148.21428571,  50.        ],
#        [152.14285714,  50.        ],
#        [156.07142857,  50.        ],
#        [160.        ,  50.        ]])

# %%
import numpy as np

# Define b range and spacing
b_vals = np.arange(15, 50, 2.4)

# Append 50 if it's not already included (within numerical tolerance)
if not np.isclose(b_vals[-1], 50):
    b_vals = np.append(b_vals, 50)

# Prepare list to hold (l, b) pairs
coords = []

for b in b_vals:
    # Convert b to radians for cosine
    b_rad = np.radians(b)
    # Longitude spacing
    delta_l = 2.4 / np.cos(b_rad)
    # Define l range for this b
    l_vals = np.arange(105, 160 + 1e-6, delta_l)
    for l in l_vals:
        coords.append((round(l, 4), round(b, 4)))  # Rounded for neatness

# Convert to numpy array for matrix-style handling
coord_array = np.array(coords)

# Print or return
for l, b in coord_array:
    print(f"l: {l:.4f}, b: {b:.4f}")
# Out:
# l: 105.0000, b: 15.0000
# l: 107.4847, b: 15.0000
# l: 109.9693, b: 15.0000
# l: 112.4540, b: 15.0000
# l: 114.9387, b: 15.0000
# l: 117.4233, b: 15.0000
# l: 119.9080, b: 15.0000
# l: 122.3926, b: 15.0000
# l: 124.8773, b: 15.0000
# l: 127.3620, b: 15.0000
# l: 129.8466, b: 15.0000
# l: 132.3313, b: 15.0000
# l: 134.8160, b: 15.0000
# l: 137.3006, b: 15.0000
# l: 139.7853, b: 15.0000
# l: 142.2699, b: 15.0000
# l: 144.7546, b: 15.0000
# l: 147.2393, b: 15.0000
# l: 149.7239, b: 15.0000
# l: 152.2086, b: 15.0000
# l: 154.6933, b: 15.0000
# l: 157.1779, b: 15.0000
# l: 159.6626, b: 15.0000
# l: 105.0000, b: 17.4000
# l: 107.5151, b: 17.4000
# l: 110.0302, b: 17.4000
# l: 112.5453, b: 17.4000
# l: 115.0604, b: 17.4000
# l: 117.5754, b: 17.4000
# l: 120.0905, b: 17.4000
# l: 122.6056, b: 17.4000
# l: 125.1207, b: 17.4000
# l: 127.6358, b: 17.4000
# l: 130.1509, b: 17.4000
# l: 132.6660, b: 17.4000
# l: 135.1811, b: 17.4000
# l: 137.6962, b: 17.4000
# l: 140.2113, b: 17.4000
# l: 142.7263, b: 17.4000
# l: 145.2414, b: 17.4000
# l: 147.7565, b: 17.4000
# l: 150.2716, b: 17.4000
# l: 152.7867, b: 17.4000
# l: 155.3018, b: 17.4000
# l: 157.8169, b: 17.4000
# l: 105.0000, b: 19.8000
# l: 107.5508, b: 19.8000
# l: 110.1016, b: 19.8000
# l: 112.6524, b: 19.8000
# l: 115.2032, b: 19.8000
# l: 117.7540, b: 19.8000
# l: 120.3048, b: 19.8000
# l: 122.8556, b: 19.8000
# l: 125.4064, b: 19.8000
# l: 127.9572, b: 19.8000
# l: 130.5080, b: 19.8000
# l: 133.0588, b: 19.8000
# l: 135.6096, b: 19.8000
# l: 138.1604, b: 19.8000
# l: 140.7112, b: 19.8000
# l: 143.2620, b: 19.8000
# l: 145.8128, b: 19.8000
# l: 148.3636, b: 19.8000
# l: 150.9144, b: 19.8000
# l: 153.4652, b: 19.8000
# l: 156.0160, b: 19.8000
# l: 158.5668, b: 19.8000
# l: 105.0000, b: 22.2000
# l: 107.5922, b: 22.2000
# l: 110.1843, b: 22.2000
# l: 112.7765, b: 22.2000
# l: 115.3686, b: 22.2000
# l: 117.9608, b: 22.2000
# l: 120.5529, b: 22.2000
# l: 123.1451, b: 22.2000
# l: 125.7372, b: 22.2000
# l: 128.3294, b: 22.2000
# l: 130.9215, b: 22.2000
# l: 133.5137, b: 22.2000
# l: 136.1059, b: 22.2000
# l: 138.6980, b: 22.2000
# l: 141.2902, b: 22.2000
# l: 143.8823, b: 22.2000
# l: 146.4745, b: 22.2000
# l: 149.0666, b: 22.2000
# l: 151.6588, b: 22.2000
# l: 154.2509, b: 22.2000
# l: 156.8431, b: 22.2000
# l: 159.4353, b: 22.2000
# l: 105.0000, b: 24.6000
# l: 107.6396, b: 24.6000
# l: 110.2792, b: 24.6000
# l: 112.9187, b: 24.6000
# l: 115.5583, b: 24.6000
# l: 118.1979, b: 24.6000
# l: 120.8375, b: 24.6000
# l: 123.4770, b: 24.6000
# l: 126.1166, b: 24.6000
# l: 128.7562, b: 24.6000
# l: 131.3958, b: 24.6000
# l: 134.0354, b: 24.6000
# l: 136.6749, b: 24.6000
# l: 139.3145, b: 24.6000
# l: 141.9541, b: 24.6000
# l: 144.5937, b: 24.6000
# l: 147.2333, b: 24.6000
# l: 149.8728, b: 24.6000
# l: 152.5124, b: 24.6000
# l: 155.1520, b: 24.6000
# l: 157.7916, b: 24.6000
# l: 105.0000, b: 27.0000
# l: 107.6936, b: 27.0000
# l: 110.3872, b: 27.0000
# l: 113.0807, b: 27.0000
# l: 115.7743, b: 27.0000
# l: 118.4679, b: 27.0000
# l: 121.1615, b: 27.0000
# l: 123.8551, b: 27.0000
# l: 126.5487, b: 27.0000
# l: 129.2422, b: 27.0000
# l: 131.9358, b: 27.0000
# l: 134.6294, b: 27.0000
# l: 137.3230, b: 27.0000
# l: 140.0166, b: 27.0000
# l: 142.7102, b: 27.0000
# l: 145.4037, b: 27.0000
# l: 148.0973, b: 27.0000
# l: 150.7909, b: 27.0000
# l: 153.4845, b: 27.0000
# l: 156.1781, b: 27.0000
# l: 158.8717, b: 27.0000
# l: 105.0000, b: 29.4000
# l: 107.7548, b: 29.4000
# l: 110.5096, b: 29.4000
# l: 113.2643, b: 29.4000
# l: 116.0191, b: 29.4000
# l: 118.7739, b: 29.4000
# l: 121.5287, b: 29.4000
# l: 124.2834, b: 29.4000
# l: 127.0382, b: 29.4000
# l: 129.7930, b: 29.4000
# l: 132.5478, b: 29.4000
# l: 135.3025, b: 29.4000
# l: 138.0573, b: 29.4000
# l: 140.8121, b: 29.4000
# l: 143.5669, b: 29.4000
# l: 146.3217, b: 29.4000
# l: 149.0764, b: 29.4000
# l: 151.8312, b: 29.4000
# l: 154.5860, b: 29.4000
# l: 157.3408, b: 29.4000
# l: 105.0000, b: 31.8000
# l: 107.8239, b: 31.8000
# l: 110.6478, b: 31.8000
# l: 113.4717, b: 31.8000
# l: 116.2955, b: 31.8000
# l: 119.1194, b: 31.8000
# l: 121.9433, b: 31.8000
# l: 124.7672, b: 31.8000
# l: 127.5911, b: 31.8000
# l: 130.4150, b: 31.8000
# l: 133.2389, b: 31.8000
# l: 136.0627, b: 31.8000
# l: 138.8866, b: 31.8000
# l: 141.7105, b: 31.8000
# l: 144.5344, b: 31.8000
# l: 147.3583, b: 31.8000
# l: 150.1822, b: 31.8000
# l: 153.0061, b: 31.8000
# l: 155.8299, b: 31.8000
# l: 158.6538, b: 31.8000
# l: 105.0000, b: 34.2000
# l: 107.9018, b: 34.2000
# l: 110.8035, b: 34.2000
# l: 113.7053, b: 34.2000
# l: 116.6071, b: 34.2000
# l: 119.5089, b: 34.2000
# l: 122.4106, b: 34.2000
# l: 125.3124, b: 34.2000
# l: 128.2142, b: 34.2000
# l: 131.1160, b: 34.2000
# l: 134.0177, b: 34.2000
# l: 136.9195, b: 34.2000
# l: 139.8213, b: 34.2000
# l: 142.7230, b: 34.2000
# l: 145.6248, b: 34.2000
# l: 148.5266, b: 34.2000
# l: 151.4284, b: 34.2000
# l: 154.3301, b: 34.2000
# l: 157.2319, b: 34.2000
# l: 105.0000, b: 36.6000
# l: 107.9895, b: 36.6000
# l: 110.9789, b: 36.6000
# l: 113.9684, b: 36.6000
# l: 116.9579, b: 36.6000
# l: 119.9474, b: 36.6000
# l: 122.9368, b: 36.6000
# l: 125.9263, b: 36.6000
# l: 128.9158, b: 36.6000
# l: 131.9052, b: 36.6000
# l: 134.8947, b: 36.6000
# l: 137.8842, b: 36.6000
# l: 140.8737, b: 36.6000
# l: 143.8631, b: 36.6000
# l: 146.8526, b: 36.6000
# l: 149.8421, b: 36.6000
# l: 152.8315, b: 36.6000
# l: 155.8210, b: 36.6000
# l: 158.8105, b: 36.6000
# l: 105.0000, b: 39.0000
# l: 108.0882, b: 39.0000
# l: 111.1764, b: 39.0000
# l: 114.2647, b: 39.0000
# l: 117.3529, b: 39.0000
# l: 120.4411, b: 39.0000
# l: 123.5293, b: 39.0000
# l: 126.6176, b: 39.0000
# l: 129.7058, b: 39.0000
# l: 132.7940, b: 39.0000
# l: 135.8822, b: 39.0000
# l: 138.9705, b: 39.0000
# l: 142.0587, b: 39.0000
# l: 145.1469, b: 39.0000
# l: 148.2351, b: 39.0000
# l: 151.3233, b: 39.0000
# l: 154.4116, b: 39.0000
# l: 157.4998, b: 39.0000
# l: 105.0000, b: 41.4000
# l: 108.1995, b: 41.4000
# l: 111.3991, b: 41.4000
# l: 114.5986, b: 41.4000
# l: 117.7981, b: 41.4000
# l: 120.9976, b: 41.4000
# l: 124.1972, b: 41.4000
# l: 127.3967, b: 41.4000
# l: 130.5962, b: 41.4000
# l: 133.7957, b: 41.4000
# l: 136.9953, b: 41.4000
# l: 140.1948, b: 41.4000
# l: 143.3943, b: 41.4000
# l: 146.5938, b: 41.4000
# l: 149.7934, b: 41.4000
# l: 152.9929, b: 41.4000
# l: 156.1924, b: 41.4000
# l: 159.3919, b: 41.4000
# l: 105.0000, b: 43.8000
# l: 108.3252, b: 43.8000
# l: 111.6504, b: 43.8000
# l: 114.9756, b: 43.8000
# l: 118.3008, b: 43.8000
# l: 121.6260, b: 43.8000
# l: 124.9512, b: 43.8000
# l: 128.2764, b: 43.8000
# l: 131.6016, b: 43.8000
# l: 134.9268, b: 43.8000
# l: 138.2520, b: 43.8000
# l: 141.5772, b: 43.8000
# l: 144.9024, b: 43.8000
# l: 148.2277, b: 43.8000
# l: 151.5529, b: 43.8000
# l: 154.8781, b: 43.8000
# l: 158.2033, b: 43.8000
# l: 105.0000, b: 46.2000
# l: 108.4675, b: 46.2000
# l: 111.9350, b: 46.2000
# l: 115.4025, b: 46.2000
# l: 118.8700, b: 46.2000
# l: 122.3375, b: 46.2000
# l: 125.8049, b: 46.2000
# l: 129.2724, b: 46.2000
# l: 132.7399, b: 46.2000
# l: 136.2074, b: 46.2000
# l: 139.6749, b: 46.2000
# l: 143.1424, b: 46.2000
# l: 146.6099, b: 46.2000
# l: 150.0774, b: 46.2000
# l: 153.5449, b: 46.2000
# l: 157.0124, b: 46.2000
# l: 105.0000, b: 48.6000
# l: 108.6292, b: 48.6000
# l: 112.2583, b: 48.6000
# l: 115.8875, b: 48.6000
# l: 119.5166, b: 48.6000
# l: 123.1458, b: 48.6000
# l: 126.7749, b: 48.6000
# l: 130.4041, b: 48.6000
# l: 134.0332, b: 48.6000
# l: 137.6624, b: 48.6000
# l: 141.2915, b: 48.6000
# l: 144.9207, b: 48.6000
# l: 148.5498, b: 48.6000
# l: 152.1790, b: 48.6000
# l: 155.8081, b: 48.6000
# l: 159.4373, b: 48.6000
# l: 105.0000, b: 50.0000
# l: 108.7337, b: 50.0000
# l: 112.4675, b: 50.0000
# l: 116.2012, b: 50.0000
# l: 119.9349, b: 50.0000
# l: 123.6687, b: 50.0000
# l: 127.4024, b: 50.0000
# l: 131.1362, b: 50.0000
# l: 134.8699, b: 50.0000
# l: 138.6036, b: 50.0000
# l: 142.3374, b: 50.0000
# l: 146.0711, b: 50.0000
# l: 149.8048, b: 50.0000
# l: 153.5386, b: 50.0000
# l: 157.2723, b: 50.0000

# %%
coord_array.shape
# Out:
# (309, 2)

# %%
coord_array
# Out:
# array([[105.    ,  15.    ],
#        [107.4847,  15.    ],
#        [109.9693,  15.    ],
#        [112.454 ,  15.    ],
#        [114.9387,  15.    ],
#        [117.4233,  15.    ],
#        [119.908 ,  15.    ],
#        [122.3926,  15.    ],
#        [124.8773,  15.    ],
#        [127.362 ,  15.    ],
#        [129.8466,  15.    ],
#        [132.3313,  15.    ],
#        [134.816 ,  15.    ],
#        [137.3006,  15.    ],
#        [139.7853,  15.    ],
#        [142.2699,  15.    ],
#        [144.7546,  15.    ],
#        [147.2393,  15.    ],
#        [149.7239,  15.    ],
#        [152.2086,  15.    ],
#        [154.6933,  15.    ],
#        [157.1779,  15.    ],
#        [159.6626,  15.    ],
#        [105.    ,  17.4   ],
#        [107.5151,  17.4   ],
#        [110.0302,  17.4   ],
#        [112.5453,  17.4   ],
#        [115.0604,  17.4   ],
#        [117.5754,  17.4   ],
#        [120.0905,  17.4   ],
#        [122.6056,  17.4   ],
#        [125.1207,  17.4   ],
#        [127.6358,  17.4   ],
#        [130.1509,  17.4   ],
#        [132.666 ,  17.4   ],
#        [135.1811,  17.4   ],
#        [137.6962,  17.4   ],
#        [140.2113,  17.4   ],
#        [142.7263,  17.4   ],
#        [145.2414,  17.4   ],
#        [147.7565,  17.4   ],
#        [150.2716,  17.4   ],
#        [152.7867,  17.4   ],
#        [155.3018,  17.4   ],
#        [157.8169,  17.4   ],
#        [105.    ,  19.8   ],
#        [107.5508,  19.8   ],
#        [110.1016,  19.8   ],
#        [112.6524,  19.8   ],
#        [115.2032,  19.8   ],
#        [117.754 ,  19.8   ],
#        [120.3048,  19.8   ],
#        [122.8556,  19.8   ],
#        [125.4064,  19.8   ],
#        [127.9572,  19.8   ],
#        [130.508 ,  19.8   ],
#        [133.0588,  19.8   ],
#        [135.6096,  19.8   ],
#        [138.1604,  19.8   ],
#        [140.7112,  19.8   ],
#        [143.262 ,  19.8   ],
#        [145.8128,  19.8   ],
#        [148.3636,  19.8   ],
#        [150.9144,  19.8   ],
#        [153.4652,  19.8   ],
#        [156.016 ,  19.8   ],
#        [158.5668,  19.8   ],
#        [105.    ,  22.2   ],
#        [107.5922,  22.2   ],
#        [110.1843,  22.2   ],
#        [112.7765,  22.2   ],
#        [115.3686,  22.2   ],
#        [117.9608,  22.2   ],
#        [120.5529,  22.2   ],
#        [123.1451,  22.2   ],
#        [125.7372,  22.2   ],
#        [128.3294,  22.2   ],
#        [130.9215,  22.2   ],
#        [133.5137,  22.2   ],
#        [136.1059,  22.2   ],
#        [138.698 ,  22.2   ],
#        [141.2902,  22.2   ],
#        [143.8823,  22.2   ],
#        [146.4745,  22.2   ],
#        [149.0666,  22.2   ],
#        [151.6588,  22.2   ],
#        [154.2509,  22.2   ],
#        [156.8431,  22.2   ],
#        [159.4353,  22.2   ],
#        [105.    ,  24.6   ],
#        [107.6396,  24.6   ],
#        [110.2792,  24.6   ],
#        [112.9187,  24.6   ],
#        [115.5583,  24.6   ],
#        [118.1979,  24.6   ],
#        [120.8375,  24.6   ],
#        [123.477 ,  24.6   ],
#        [126.1166,  24.6   ],
#        [128.7562,  24.6   ],
#        [131.3958,  24.6   ],
#        [134.0354,  24.6   ],
#        [136.6749,  24.6   ],
#        [139.3145,  24.6   ],
#        [141.9541,  24.6   ],
#        [144.5937,  24.6   ],
#        [147.2333,  24.6   ],
#        [149.8728,  24.6   ],
#        [152.5124,  24.6   ],
#        [155.152 ,  24.6   ],
#        [157.7916,  24.6   ],
#        [105.    ,  27.    ],
#        [107.6936,  27.    ],
#        [110.3872,  27.    ],
#        [113.0807,  27.    ],
#        [115.7743,  27.    ],
#        [118.4679,  27.    ],
#        [121.1615,  27.    ],
#        [123.8551,  27.    ],
#        [126.5487,  27.    ],
#        [129.2422,  27.    ],
#        [131.9358,  27.    ],
#        [134.6294,  27.    ],
#        [137.323 ,  27.    ],
#        [140.0166,  27.    ],
#        [142.7102,  27.    ],
#        [145.4037,  27.    ],
#        [148.0973,  27.    ],
#        [150.7909,  27.    ],
#        [153.4845,  27.    ],
#        [156.1781,  27.    ],
#        [158.8717,  27.    ],
#        [105.    ,  29.4   ],
#        [107.7548,  29.4   ],
#        [110.5096,  29.4   ],
#        [113.2643,  29.4   ],
#        [116.0191,  29.4   ],
#        [118.7739,  29.4   ],
#        [121.5287,  29.4   ],
#        [124.2834,  29.4   ],
#        [127.0382,  29.4   ],
#        [129.793 ,  29.4   ],
#        [132.5478,  29.4   ],
#        [135.3025,  29.4   ],
#        [138.0573,  29.4   ],
#        [140.8121,  29.4   ],
#        [143.5669,  29.4   ],
#        [146.3217,  29.4   ],
#        [149.0764,  29.4   ],
#        [151.8312,  29.4   ],
#        [154.586 ,  29.4   ],
#        [157.3408,  29.4   ],
#        [105.    ,  31.8   ],
#        [107.8239,  31.8   ],
#        [110.6478,  31.8   ],
#        [113.4717,  31.8   ],
#        [116.2955,  31.8   ],
#        [119.1194,  31.8   ],
#        [121.9433,  31.8   ],
#        [124.7672,  31.8   ],
#        [127.5911,  31.8   ],
#        [130.415 ,  31.8   ],
#        [133.2389,  31.8   ],
#        [136.0627,  31.8   ],
#        [138.8866,  31.8   ],
#        [141.7105,  31.8   ],
#        [144.5344,  31.8   ],
#        [147.3583,  31.8   ],
#        [150.1822,  31.8   ],
#        [153.0061,  31.8   ],
#        [155.8299,  31.8   ],
#        [158.6538,  31.8   ],
#        [105.    ,  34.2   ],
#        [107.9018,  34.2   ],
#        [110.8035,  34.2   ],
#        [113.7053,  34.2   ],
#        [116.6071,  34.2   ],
#        [119.5089,  34.2   ],
#        [122.4106,  34.2   ],
#        [125.3124,  34.2   ],
#        [128.2142,  34.2   ],
#        [131.116 ,  34.2   ],
#        [134.0177,  34.2   ],
#        [136.9195,  34.2   ],
#        [139.8213,  34.2   ],
#        [142.723 ,  34.2   ],
#        [145.6248,  34.2   ],
#        [148.5266,  34.2   ],
#        [151.4284,  34.2   ],
#        [154.3301,  34.2   ],
#        [157.2319,  34.2   ],
#        [105.    ,  36.6   ],
#        [107.9895,  36.6   ],
#        [110.9789,  36.6   ],
#        [113.9684,  36.6   ],
#        [116.9579,  36.6   ],
#        [119.9474,  36.6   ],
#        [122.9368,  36.6   ],
#        [125.9263,  36.6   ],
#        [128.9158,  36.6   ],
#        [131.9052,  36.6   ],
#        [134.8947,  36.6   ],
#        [137.8842,  36.6   ],
#        [140.8737,  36.6   ],
#        [143.8631,  36.6   ],
#        [146.8526,  36.6   ],
#        [149.8421,  36.6   ],
#        [152.8315,  36.6   ],
#        [155.821 ,  36.6   ],
#        [158.8105,  36.6   ],
#        [105.    ,  39.    ],
#        [108.0882,  39.    ],
#        [111.1764,  39.    ],
#        [114.2647,  39.    ],
#        [117.3529,  39.    ],
#        [120.4411,  39.    ],
#        [123.5293,  39.    ],
#        [126.6176,  39.    ],
#        [129.7058,  39.    ],
#        [132.794 ,  39.    ],
#        [135.8822,  39.    ],
#        [138.9705,  39.    ],
#        [142.0587,  39.    ],
#        [145.1469,  39.    ],
#        [148.2351,  39.    ],
#        [151.3233,  39.    ],
#        [154.4116,  39.    ],
#        [157.4998,  39.    ],
#        [105.    ,  41.4   ],
#        [108.1995,  41.4   ],
#        [111.3991,  41.4   ],
#        [114.5986,  41.4   ],
#        [117.7981,  41.4   ],
#        [120.9976,  41.4   ],
#        [124.1972,  41.4   ],
#        [127.3967,  41.4   ],
#        [130.5962,  41.4   ],
#        [133.7957,  41.4   ],
#        [136.9953,  41.4   ],
#        [140.1948,  41.4   ],
#        [143.3943,  41.4   ],
#        [146.5938,  41.4   ],
#        [149.7934,  41.4   ],
#        [152.9929,  41.4   ],
#        [156.1924,  41.4   ],
#        [159.3919,  41.4   ],
#        [105.    ,  43.8   ],
#        [108.3252,  43.8   ],
#        [111.6504,  43.8   ],
#        [114.9756,  43.8   ],
#        [118.3008,  43.8   ],
#        [121.626 ,  43.8   ],
#        [124.9512,  43.8   ],
#        [128.2764,  43.8   ],
#        [131.6016,  43.8   ],
#        [134.9268,  43.8   ],
#        [138.252 ,  43.8   ],
#        [141.5772,  43.8   ],
#        [144.9024,  43.8   ],
#        [148.2277,  43.8   ],
#        [151.5529,  43.8   ],
#        [154.8781,  43.8   ],
#        [158.2033,  43.8   ],
#        [105.    ,  46.2   ],
#        [108.4675,  46.2   ],
#        [111.935 ,  46.2   ],
#        [115.4025,  46.2   ],
#        [118.87  ,  46.2   ],
#        [122.3375,  46.2   ],
#        [125.8049,  46.2   ],
#        [129.2724,  46.2   ],
#        [132.7399,  46.2   ],
#        [136.2074,  46.2   ],
#        [139.6749,  46.2   ],
#        [143.1424,  46.2   ],
#        [146.6099,  46.2   ],
#        [150.0774,  46.2   ],
#        [153.5449,  46.2   ],
#        [157.0124,  46.2   ],
#        [105.    ,  48.6   ],
#        [108.6292,  48.6   ],
#        [112.2583,  48.6   ],
#        [115.8875,  48.6   ],
#        [119.5166,  48.6   ],
#        [123.1458,  48.6   ],
#        [126.7749,  48.6   ],
#        [130.4041,  48.6   ],
#        [134.0332,  48.6   ],
#        [137.6624,  48.6   ],
#        [141.2915,  48.6   ],
#        [144.9207,  48.6   ],
#        [148.5498,  48.6   ],
#        [152.179 ,  48.6   ],
#        [155.8081,  48.6   ],
#        [159.4373,  48.6   ],
#        [105.    ,  50.    ],
#        [108.7337,  50.    ],
#        [112.4675,  50.    ],
#        [116.2012,  50.    ],
#        [119.9349,  50.    ],
#        [123.6687,  50.    ],
#        [127.4024,  50.    ],
#        [131.1362,  50.    ],
#        [134.8699,  50.    ],
#        [138.6036,  50.    ],
#        [142.3374,  50.    ],
#        [146.0711,  50.    ],
#        [149.8048,  50.    ],
#        [153.5386,  50.    ],
#        [157.2723,  50.    ]])
